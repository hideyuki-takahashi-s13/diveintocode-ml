# %% [markdown]
# # 【問題1】データセットの取得
# pd.read_csv()を使用して、変数に格納してください。

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/Users/takahashihideyuki/dive/diveintocode-ml/Week3/train.csv", encoding="utf-8")

df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# # 【問題2】データセット自体の調査
# KaggleのOverviewページや、Dataページの「Data fields」などを読みながら、どのようなデータセットかを説明してください。

# %% [markdown]
# アイオワ州エイムスの各住宅の最終的な価格を予測する為の、「MoSold：販売月、YrSold：販売年、YearBuilt：元の建設日、YearRemodAdd：改造日、GarageType：ガレージのタイプ、PoolQC：プールの品質」といった、（ほぼ）すべての側面を説明する79の説明変数が格納されている。

# %% [markdown]
# # 【問題3】データの確認
# データを確認していきます。コードとマークダウンを組み合わせてレポートしてください。
# - 各特徴量がどういったものかを見る。（数値データか文字データなど）
# - 今回の目的変数はどの列か確認する。
# - 特徴量の平均値と標準偏差、四分位数を一度に表示させる。

# %% [markdown]
# #### ・各特徴量がどういったものかを見る。（数値データか文字データなど）
# 数値データと文字データが混在している。また、欠損値が含まれている。

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.isnull().sum()[df.isnull().sum()>0].sort_values()    #欠損値があるデータを抽出し、欠損値数でソート
# Out:
# Electrical         1
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# BsmtExposure      38
# BsmtFinType2      38
# GarageCond        81
# GarageQual        81
# GarageFinish      81
# GarageType        81
# GarageYrBlt       81
# LotFrontage      259
# FireplaceQu      690
# Fence           1179
# Alley           1369
# MiscFeature     1406
# PoolQC          1453
# dtype: int64

# %% [markdown]
# #### ・今回の目的変数はどの列か確認する。
# SalePrice - the property's sale price in dollars. This is the target variable　※Kaggle データフィールドより抜粋<br>
# 目的変数：SalePriceは、0列目から数えた場合の80列目である。

# %%
df.columns.get_loc("SalePrice")
# Out:
# 80

# %% [markdown]
# #### ・特徴量の平均値と標準偏差、四分位数を一度に表示させる。

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
# # 【問題4】欠損値への対応
# 欠損値に関して以下のことを行い、レポートしてください。
# - 各特徴量の欠損値の有無を確認する。
#
# 欠損値の確認にはmissingnoというライブラリを活用しましょう。このライブラリにより欠損値の有無が可視化できます。インストールや使い方に関しては以下のページをご覧ください。<br>
# ResidentMario/missingno: Missing data visualization module for Python.
# - 欠損値が何パーセント含まれるかを確認する。
# - 5つ以上欠損値がある特徴量（列）は削除する。
# - 欠損値があるサンプル（行）は削除する。

# %% [markdown]
# #### ・各特徴量の欠損値の有無を確認する。
# 欠損値がある特徴量は一つ下のセルを参照。<br>
# 二つ下のセルより、missingnoにて棒グラフでデータを可視化。（見易くする為４分割で出力）

# %%
#欠損値がある特徴量と欠損値数を抽出
df.isnull().sum()[df.isnull().sum()>0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
import missingno as msno
import matplotlib.pyplot as plt
# %matplotlib inline

#カラム番号０〜１９を描画
msno.bar(df.iloc[:, :20], figsize=(15, 5))

plt.show()

# %%
#カラム番号２０〜３９を描画
msno.bar(df.iloc[:, 20:40], figsize=(15, 5))
plt.show()

# %%
#カラム番号４０〜５９を描画
msno.bar(df.iloc[:, 40:60], figsize=(15, 5))
plt.show()

# %%
#カラム番号６０〜８０を描画
msno.bar(df.iloc[:, 60:81], figsize=(15, 5))
plt.show()

# %% [markdown]
# #### ・欠損値が何パーセント含まれるかを確認する。

# %%
pd.options.display.float_format = '{:.2f}'.format

df_missing_n = df.isnull().sum()[df.isnull().sum()>0]    #欠損値がある特徴量と欠損値数を抽出
df_missing_ratio = (df_missing_n / len(df)) * 100    #特徴量毎の欠損値率を算出
df_missing = pd.concat([df_missing_n, df_missing_ratio], axis=1)    #欠損値率をマージ
df_missing.columns = ["Total", "missing_ratio[%]"]    #カラム名を付与

df_missing.sort_values(by="Total", ascending=False)    #降順で出力
# Out:
#               Total  missing_ratio[%]
# PoolQC         1453             99.52
# MiscFeature    1406             96.30
# Alley          1369             93.77
# Fence          1179             80.75
# FireplaceQu     690             47.26
# LotFrontage     259             17.74
# GarageType       81              5.55
# GarageYrBlt      81              5.55
# GarageFinish     81              5.55
# GarageQual       81              5.55
# GarageCond       81              5.55
# BsmtExposure     38              2.60
# BsmtFinType2     38              2.60
# BsmtFinType1     37              2.53
# BsmtCond         37              2.53
# BsmtQual         37              2.53
# MasVnrArea        8              0.55
# MasVnrType        8              0.55
# Electrical        1              0.07

# %% [markdown]
# #### ・5つ以上欠損値がある特徴量（列）は削除する。

# %%
df_drop_columns = df.dropna(axis=1, thresh=len(df)-4)
df_drop_columns
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 0        1          60       RL     8450   Pave      Reg         Lvl
# 1        2          20       RL     9600   Pave      Reg         Lvl
# 2        3          60       RL    11250   Pave      IR1         Lvl
# 3        4          70       RL     9550   Pave      IR1         Lvl
# 4        5          60       RL    14260   Pave      IR1         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# 1455  1456          60       RL     7917   Pave      Reg         Lvl
# 1456  1457          20       RL    13175   Pave      Reg         Lvl
# 1457  1458          70       RL     9042   Pave      Reg         Lvl
# 1458  1459          20       RL     9717   Pave      Reg         Lvl
# 1459  1460          20       RL     9937   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %% [markdown]
# #### ・欠損値があるサンプル（行）は削除する。

# %%
df_drop_rows = df.dropna()
df_drop_rows
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# ...

# %% [markdown]
# # 【問題5】用語の調査
# 以下の２つの単語を知る必要があります。これらを調査してまとめてください。<br>
# - 尖度
# - 歪度

# %% [markdown]
# ### 尖度（せんど）とは
# 分布が正規分布からどれだけ尖っているかを表す統計量で、山の尖り度と裾の広がり度を示します。サンプルサイズをn、各データの平均値を、標準偏差をsとすると尖度は次の式から求められます。![image.png](attachment:image.png)
#
# 正規分布より尖った分布（データが平均付近に集中し、分布の裾が重い）のときには正の値を、正規分布より扁平な分布（データが平均付近から散らばり、分布の裾が軽い）のときには負の値をとります。正規分布の場合には0になります。

# %% [markdown]
# ### 歪度（わいど）とは
# 分布が正規分布からどれだけ歪んでいるかを表す統計量で、左右対称性を示す指標のことです。サンプルサイズをn、各データの平均値を、標準偏差をsとすると歪度は次の式から求められます。![image.png](attachment:image.png)
#
# 「右裾が長い」もしくは「右に歪んだ」もしくは「左に偏った」分布のときには正の値を、「左裾が長い」もしくは「左に歪んだ」もしくは「右に偏った」分布のときには負の値をとります。左右対称の分布（例えば正規分布）の場合には0になります。

# %% [markdown]
# # 【問題6】分布の確認
# seabornのsns.distplot()を使い目的変数の分布を表示し、「尖度」と「歪度」も算出する。<br>
# 目的変数に対して対数変換を行う。<br>
# 対数変換したものに対して分布を表示し、「尖度」と「歪度」も算出する。<br>
#
# 対数変換の前後での変化を「正規分布」という言葉を含めて説明してください。<br>
# このように加工することで予測時の精度を上げることができます。<br>

# %%
import seaborn as sns

# sns.distplot()を使い目的変数の分布を表示
sns.distplot(df["SalePrice"])
plt.show()

print("尖度：{}".format(df["SalePrice"].kurt()))    # 尖度を算出
print("歪度：{}".format(df["SalePrice"].skew()))    # 歪度を算出
# Out:
# 尖度：6.536281860064529
# 歪度：1.8828757597682129

# %%
# 目的変数に対して対数変換を行う
df_target_log = df["SalePrice"].apply(np.log)

# sns.distplot()を使い対数変換後の目的変数の分布を表示
sns.distplot(df_target_log)
plt.show()

print("尖度：{}".format(df_target_log.kurt()))    # 尖度を算出
print("歪度：{}".format(df_target_log.skew()))    # 歪度を算出
# Out:
# 尖度：0.8095319958036296
# 歪度：0.12133506220520406

# %% [markdown]
# #### 対数変換の前後での変化を「正規分布」という言葉を含めて説明
# 対数変換を行うことで正規分布に近づいている。尖度及び歪度も０に近づいており、定量的にも正規分布に近づいたことを示している。

# %% [markdown]
# # 【問題7】相関係数の確認
# 特徴量の確認をしていきます。それぞれに対してマークダウンで説明や考察を書いてください。<br>
# - 相関係数行列のヒートマップを作り、相関係数の高い関係を見つける。
# - 目的変数との相関の高い特徴量10個を選び、これらだけの相関係数行列ヒートマップを作る。
# - 選んだ10個の特徴量が何か表しているかをKaggleのDataDescriptionの記述を参考に日本語でまとめる。
# - 選んだ10個の特徴量の中でお互いの相関係数が高い組み合わせを3つ探し出す。

# %% [markdown]
# #### ・相関係数行列のヒートマップを作り、相関係数の高い関係を見つける。
# ヒートマップを俯瞰して見ると、比較的データフレームの列数の若い方に相関係数の高い特徴量が多い。

# %%
# 特徴量に関する相関係数行列を作る
corr_df = df.corr(method='pearson')
corr_df
# Out:
#                  Id  MSSubClass  LotFrontage  LotArea  OverallQual  \
# Id             1.00        0.01        -0.01    -0.03        -0.03
# MSSubClass     0.01        1.00        -0.39    -0.14         0.03
# LotFrontage   -0.01       -0.39         1.00     0.43         0.25
# LotArea       -0.03       -0.14         0.43     1.00         0.11
# OverallQual   -0.03        0.03         0.25     0.11         1.00
# OverallCond    0.01       -0.06        -0.06    -0.01        -0.09
# YearBuilt     -0.01        0.03         0.12     0.01         0.57
# YearRemodAdd  -0.02        0.04         0.09     0.01         0.55
# MasVnrArea    -0.05        0.02         0.19     0.10         0.41
# BsmtFinSF1    -0.01       -0.07         0.23     0.21         0.24
# BsmtFinSF2    -0.01       -0.07         0.05     0.11        -0.06
# BsmtUnfSF     -0.01       -0.14         0.13    -0.00         0.31
# TotalBsmtSF   -0.02       -0.24         0.39     0.26         0.54
# ...

# %%
# 相関係数行列のヒートマップを作る
fig, ax = plt.subplots(figsize=(30,30))
g = sns.heatmap(corr_df, vmin=-1.0, vmax=1.0, center=0, annot=True, fmt='.2f', cmap="RdBu_r")

plt.show()

# %% [markdown]
# #### ・目的変数との相関の高い特徴量10個を選び、これらだけの相関係数行列ヒートマップを作る。

# %%
#目的変数との相関の高い特徴量10個を抽出
high_corr_columns = abs(corr_df["SalePrice"]).sort_values()[-11:].index.values
df[high_corr_columns]
# Out:
#       YearRemodAdd  YearBuilt  TotRmsAbvGrd  FullBath  1stFlrSF  TotalBsmtSF  \
# 0             2003       2003             8         2       856          856
# 1             1976       1976             6         2      1262         1262
# 2             2002       2001             6         2       920          920
# 3             1970       1915             7         1       961          756
# 4             2000       2000             9         2      1145         1145
# ...            ...        ...           ...       ...       ...          ...
# 1455          2000       1999             7         2       953          953
# 1456          1988       1978             7         2      2073         1542
# 1457          2006       1941             9         2      1188         1152
# 1458          1996       1950             5         1      1078         1078
# 1459          1965       1965             6         1      1256         1256
#
# ...

# %%
#相関の高い特徴量10個だけの相関数行列を作成
high_corr_df = df[high_corr_columns].corr(method='pearson')
high_corr_df
# Out:
#               YearRemodAdd  YearBuilt  TotRmsAbvGrd  FullBath  1stFlrSF  \
# YearRemodAdd          1.00       0.59          0.19      0.44      0.24
# YearBuilt             0.59       1.00          0.10      0.47      0.28
# TotRmsAbvGrd          0.19       0.10          1.00      0.55      0.41
# FullBath              0.44       0.47          0.55      1.00      0.38
# 1stFlrSF              0.24       0.28          0.41      0.38      1.00
# TotalBsmtSF           0.29       0.39          0.29      0.32      0.82
# GarageArea            0.37       0.48          0.34      0.41      0.49
# GarageCars            0.42       0.54          0.36      0.47      0.44
# GrLivArea             0.29       0.20          0.83      0.63      0.57
# OverallQual           0.55       0.57          0.43      0.55      0.48
# SalePrice             0.51       0.52          0.53      0.56      0.61
#
#               TotalBsmtSF  GarageArea  GarageCars  GrLivArea  OverallQual  \
# ...

# %%
# 相関の高い特徴量10個だけの相関係数行列ヒートマップを作る
fig, ax = plt.subplots(figsize=(20,10))
g = sns.heatmap(high_corr_df, vmin=-1.0, vmax=1.0, center=0, annot=True, fmt='.2f', cmap="RdBu_r")

plt.show()

# %% [markdown]
# #### ・選んだ10個の特徴量が何か表しているかをKaggleのDataDescriptionの記述を参考に日本語でまとめる。
# 目的変数（SalePrice）と最も相関が高い説明変数は、『OverallQual：全体的な材料と仕上げの品質』であり、質の良さが販売価格に大きく関係している。<br>
# その次に相関があるのは『GrLivArea：グレード以上のリビングエリアの広さ』であり、リビングの広さも重要視されている。<br>
# 以降は相関係数0.7未満でありやや相関がある程度となるが、ガレージやフロア面積の広さ等も販売価格に影響していると考えられる。
#
# <!-- YearRemodAdd：改造日
# YearBuilt：元の建設日
# TotRmsAbvGrd：グレードを超える部屋の合計（バスルームは含まれません）
# FullBath：グレードを超えるフルバスルーム
# 1stFlrSF：1階の平方フィート
# TotalBsmtSF：地下面積の合計平方フィート
# GarageArea：ガレージの平方フィートでのサイズ
# GarageCars：車の容量でのガレージのサイズ
# GrLivArea：グレード（地上）のリビングエリアの平方フィート
# OverallQual：全体的な材料と仕上げの品質 -->

# %% [markdown]
# #### ・選んだ10個の特徴量の中でお互いの相関係数が高い組み合わせを3つ探し出す。

# %%
#相関係数が高い組み合わせでソート
high_corr_sort_df = pd.DataFrame(high_corr_df.unstack()).sort_values(by=0, ascending = False)

#相関係数＝１　を排除
high_corr_sort_df_true = high_corr_sort_df[high_corr_sort_df[0] < 1]

#相関係数が高い組み合わせ上位3組を抽出
upper_3 = high_corr_sort_df_true[0:6:2]
upper_3.columns = ["correlation_coefficient"]
upper_3
# Out:
#                           correlation_coefficient
# GarageArea   GarageCars                      0.88
# TotRmsAbvGrd GrLivArea                       0.83
# 1stFlrSF     TotalBsmtSF                     0.82
